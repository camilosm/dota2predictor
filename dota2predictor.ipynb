# %%
from dota2predictor import Dota2Predictor

predictor = Dota2Predictor('data/', 'bigdata.json')

predictor.parse_bigdata(100000, '6.85')

print('Only heroes as features:')
predictor.analise_data('heroes')
print('Only advantages as features:')
predictor.analise_data('advantages')
print('Heroes and advantages as features:')
predictor.analise_data('all')
# Out:
# Parsing: 100%|██████████| 100000/100000 [14:29<00:00, 115.05it/s]
# Parsed, got 100000 usefull matches.
# Only heroes as features:
#               precision    recall  f1-score   support
#
#            0       0.50      0.43      0.47     11985
#            1       0.54      0.60      0.57     13015
#
#     accuracy                           0.52     25000
#    macro avg       0.52      0.52      0.52     25000
# weighted avg       0.52      0.52      0.52     25000
#               precision    recall  f1-score   support
#
#            0       0.48      0.46      0.47     11985
#            1       0.52      0.55      0.53     13015
#
#     accuracy                           0.50     25000
#    macro avg       0.50      0.50      0.50     25000
# weighted avg       0.50      0.50      0.50     25000
#
# Only advantages as features:
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70     11884
#            1       0.73      0.73      0.73     13116
#
#     accuracy                           0.71     25000
#    macro avg       0.71      0.71      0.71     25000
# weighted avg       0.71      0.71      0.71     25000
#               precision    recall  f1-score   support
#
#            0       0.69      0.69      0.69     11884
#            1       0.72      0.72      0.72     13116
#
#     accuracy                           0.71     25000
#    macro avg       0.71      0.71      0.71     25000
# weighted avg       0.71      0.71      0.71     25000
#
# Heroes and advantages as features:
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73     11979
#            1       0.75      0.76      0.76     13021
#
#     accuracy                           0.75     25000
#    macro avg       0.75      0.75      0.75     25000
# weighted avg       0.75      0.75      0.75     25000
#               precision    recall  f1-score   support
#
#            0       0.70      0.69      0.70     11979
#            1       0.72      0.73      0.72     13021
#
#     accuracy                           0.71     25000
#    macro avg       0.71      0.71      0.71     25000
# weighted avg       0.71      0.71      0.71     25000
