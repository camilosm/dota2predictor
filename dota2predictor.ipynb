# %%
from dota2predictor import Dota2Predictor

predictor = Dota2Predictor('data/', 'bigdata.json')

predictor.parse_bigdata(100000, '6.85')

print('Only heroes as features:')
predictor.analise_data('heroes')
print('Only advantages as features:')
predictor.analise_data('advantages')
print('Heroes and advantages as features:')
predictor.analise_data('all')
# Out:
# Parsing: 100%|██████████| 10000/10000 [01:29<00:00, 112.01it/s]
# Parsed, got 10000 usefull matches.
# Only heroes as features:
#               precision    recall  f1-score   support
#
#            0       0.49      0.46      0.48      1191
#            1       0.54      0.56      0.55      1309
#
#     accuracy                           0.52      2500
#    macro avg       0.51      0.51      0.51      2500
# weighted avg       0.51      0.52      0.51      2500
#               precision    recall  f1-score   support
#
#            0       0.50      0.49      0.49      1191
#            1       0.54      0.54      0.54      1309
#
#     accuracy                           0.52      2500
#    macro avg       0.52      0.52      0.52      2500
# weighted avg       0.52      0.52      0.52      2500
#
# Only advantages as features:
#               precision    recall  f1-score   support
#
#            0       0.68      0.69      0.69      1192
# ...
